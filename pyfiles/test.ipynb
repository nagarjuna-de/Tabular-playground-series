# %%
import pandas as pd
import numpy as np
import datetime
import holidays
import seaborn as sns


from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    row_id                 time  x  y direction  congestion
# 0       0  1991-04-01 00:00:00  0  0        EB          70
# 1       1  1991-04-01 00:00:00  0  0        NB          49
# 2       2  1991-04-01 00:00:00  0  0        SB          24
# 3       3  1991-04-01 00:00:00  0  1        EB          18
# 4       4  1991-04-01 00:00:00  0  1        NB          60

# %%
def prepo(data):
    # dropping row_id
    data.drop('row_id', axis=1, inplace=True)

    ## Creating individual columns for time column(1991-04-01 03:20:00 --- year-month-day  Hours:minutes:seconds)
    data['year'] = data['time'].apply(lambda row: row[:4])
    data['month'] = data['time'].apply(lambda row: row.split('-')[1][:2] )
    data['date'] = data['time'].apply(lambda row: row.split('-')[2][:2])
    data['hour'] = data['time'].apply(lambda row: row.split(':')[0][-2:])
    data['minute'] = data['time'].apply(lambda row: row.split(':')[1][-2:])
    data['c_date'] = data['time'].apply(lambda row: row.split(' ')[0])

    ## Chainging dataframe dtypes
    data = data.astype({'year':'int64','month':'int64', 'date':'int64','minute':'int64',
                        'x':'str','y':'str', 'direction':'str', 'hour':'int64' })

    ## Creating new _column by combining x,y,& direction.
    data['road_coord']= data['x']+data['y']+data['direction']

    ### Creating a new column of holiday.
    hol_list = []
    us_holidays = holidays.US()
    for i in data['c_date']:
        if us_holidays.get(f'{i}') == None:
            hol_list.append(0)
        else:
            hol_list.append(1)

    data['is_holiday'] = hol_list


    ## Creating new column is_weekday
    dt_list = []
    for i,j in enumerate(data['c_date']):
        day_type = datetime.date(data['year'].iloc[i],data['month'].iloc[i],data['date'].iloc[i])
        dy = day_type.weekday()
        dt_list.append(dy)
    data['week_num'] = dt_list

    ## Categorizing month column --- 1-10--0(start-month), 11-20--1(mid_month), (21-30)-- end month.
    data['month_cat'] = pd.cut(data['date'], bins=[0,10,20,31], labels=[0,1,2])

    ## Categorizing is_weekday column 0-Weekday, 1-Weekend
    data['is_weekday'] = pd.cut(data['week_num'], bins=[-1,4,6], labels = [0, 1])
    # Season 0- spring and 1-summer.
    data['season'] = pd.cut(data['month'], bins=[3,6,9], labels = [0, 1])
    ## Categorizing new column based on day timings
    data['m_a_e_n'] = pd.cut(data['hour'], bins=[4,11,16,21], labels = [0, 1,2])
    data = data.astype({'m_a_e_n':'float64'})
    data['m_a_e_n'].fillna(3, inplace=True)
    data = data.astype({'m_a_e_n':'int64'})

    ## Encoding the highway code
    le = LabelEncoder()
    data['highway_code']= le.fit_transform(data['road_coord'])
    return data

# %%
data = prepo(data)
data.head()
# Out:
#                   time  x  y direction  congestion  year  month  date  hour  \
# 0  1991-04-01 00:00:00  0  0        EB          70  1991      4     1     0
# 1  1991-04-01 00:00:00  0  0        NB          49  1991      4     1     0
# 2  1991-04-01 00:00:00  0  0        SB          24  1991      4     1     0
# 3  1991-04-01 00:00:00  0  1        EB          18  1991      4     1     0
# 4  1991-04-01 00:00:00  0  1        NB          60  1991      4     1     0
#
#    minute      c_date road_coord  is_holiday  week_num month_cat is_weekday  \
# 0       0  1991-04-01       00EB           0         0         0          0
# 1       0  1991-04-01       00NB           0         0         0          0
# 2       0  1991-04-01       00SB           0         0         0          0
# 3       0  1991-04-01       01EB           0         0         0          0
# 4       0  1991-04-01       01NB           0         0         0          0
#
#   season  m_a_e_n  highway_code
# 0      0        3             0
# 1      0        3             1
# 2      0        3             2
# 3      0        3             3
# 4      0        3             4

# %%
data = data.drop(['time','x','y','direction','year','c_date','road_coord','hour','minute','month','date'], axis=1)
print(data.shape)
data.dtypes
# Out:
# (848835, 8)
# congestion         int64
# is_holiday         int64
# week_num           int64
# month_cat       category
# is_weekday      category
# season          category
# m_a_e_n            int64
# highway_code       int32
# dtype: object

# %%
data = data.astype({'month_cat':'int64','is_weekday':'int64', 'season':'int64'})
data.dtypes
# Out:
# congestion      int64
# is_holiday      int64
# week_num        int64
# month_cat       int64
# is_weekday      int64
# season          int64
# m_a_e_n         int64
# highway_code    int32
# dtype: object

# %%
def pairing(data, seq_len=195):
    x=[]
    y =[]
    for i in range(0, ((data.shape[0])-(seq_len+1)), seq_len+1):
        shp = (seq_len, data.shape[1] )
        seq = np.zeros(shp)

        for j in range(seq_len):
            seq[j] = data.values[i+j]

        x.append(seq.flatten())  # flattening the matrix and appending it to the x list
        y.append( data["congestion"][i+seq_len] )  # appending the target to the y list 
        
    return np.array(x), np.array(y)

# %%
x,y = pairing(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\rnr31\Documents\GitHub\Tabular-playground-series\pyfiles\test.ipynb Cell 8' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Tabular-playground-series/pyfiles/test.ipynb#ch0000007?line=0'>1</a> x,y = pairing(data)
#
# c:\Users\rnr31\Documents\GitHub\Tabular-playground-series\pyfiles\test.ipynb Cell 7' in pairing(data, seq_len)
#       <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Tabular-playground-series/pyfiles/test.ipynb#ch0000006?line=5'>6</a> seq = np.zeros(shp)
#       <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Tabular-playground-series/pyfiles/test.ipynb#ch0000006?line=7'>8</a> for j in range(seq_len):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Tabular-playground-series/pyfiles/test.ipynb#ch0000006?line=8'>9</a>     seq[j] = data.values[i+j]
#      <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Tabular-playground-series/pyfiles/test.ipynb#ch0000006?line=10'>11</a> x.append(seq.flatten())  # flattening the matrix and appending it to the x list
#      <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Tabular-playground-series/pyfiles/test.ipynb#ch0000006?line=11'>12</a> y.append( data["congestion"][i+seq_len] )  # appending the target to the y list
#
# File ~\anaconda3\envs\ds22\lib\site-packages\pandas\core\generic.py:5343, in NDFrame.values(self)
#    <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5269'>5270</a> """
#    <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5270'>5271</a> Return a Numpy representation of the DataFrame.
#    <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5271'>5272</a>
#    (...)
#    <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5339'>5340</a>        ['monkey', nan, None]], dtype=object)
#    <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5340'>5341</a> """
#    <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5341'>5342</a> self._consolidate_inplace()
# -> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/generic.py?line=5342'>5343</a> return self._mgr.as_array(transpose=self._AXIS_REVERSED)
#
# File ~\anaconda3\envs\ds22\lib\site-packages\pandas\core\internals\managers.py:853, in BlockManager.as_array(self, transpose, dtype, copy, na_value)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=850'>851</a>             arr = arr.astype(dtype, copy=False)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=851'>852</a> else:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=852'>853</a>     arr = self._interleave(dtype=dtype, na_value=na_value)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=853'>854</a>     # The underlying data was copied within _interleave
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=854'>855</a>     copy = False
#
# File ~\anaconda3\envs\ds22\lib\site-packages\pandas\core\internals\managers.py:893, in BlockManager._interleave(self, dtype, na_value)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=890'>891</a>     else:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=891'>892</a>         arr = blk.get_values(dtype)
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=892'>893</a>     result[rl.indexer] = arr
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=893'>894</a>     itemmask[rl.indexer] = 1
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/ds22/lib/site-packages/pandas/core/internals/managers.py?line=895'>896</a> if not itemmask.all():
#
# KeyboardInterrupt:

# %%
x.shape

# %%
# df = pd.DataFrame(x)
# df.to_csv('x.csv')
# df_y = pd.DataFrame(y)
# df_y.to_csv('y.csv')
